# %%
import pandas as pd
import numpy as np

# %%
inter_df = pd.read_csv('Interchange.csv')
inter_df
# Out:
#                      origins               destination  distance  duration  \
# 0               MRT พหลโยธิน        BTS ห้าแยกลาดพร้าว         0         0
# 1             MRT สวนจตุจักร                BTS หมอชิต         0         0
# 2                MRT บางหว้า               BTS บางหว้า         0         0
# 3                   MRT สีลม               BTS ศาลาแดง         0         0
# 4               MRT สุขุมวิท                  BTS อโศก         0         0
# 5               MRT เพชรบุรี    AIR PORT LINK MAKKASAN         0         0
# 6                  BTS พญาไท  AIR PORT LINK PHAYA THAI         0         0
# 7         BTS ห้าแยกลาดพร้าว              MRT พหลโยธิน         0         0
# 8                 BTS หมอชิต            MRT สวนจตุจักร         0         0
# 9                BTS บางหว้า               MRT บางหว้า         0         0
# 10               BTS ศาลาแดง                  MRT สีลม         0         0
# ...

# %%
inter_df.to_json('nodes-inter.json', orient="records")
